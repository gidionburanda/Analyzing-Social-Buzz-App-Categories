# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import re
import string
import matplotlib.pyplot as plt

# %%
df_content = pd.read_csv("/content/Content.csv", index_col = 0 )
df_content
# Out:
#                                Content ID  \
# 0    97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1    9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2    230c4e4d-70c3-461d-b42c-ec09396efb3f
# 3    356fff80-da4d-4785-9f43-bc1261031dc6
# 4    01ab84dd-6364-4236-abbb-3f237db77180
# ..                                    ...
# 995  b4cef9ef-627b-41d7-a051-5961b0204ebb
# 996  7a79f4e4-3b7d-44dc-bdef-bc990740252c
# 997  435007a5-6261-4d8b-b0a4-55fdc189754b
# 998  4e4c9690-c013-4ee7-9e66-943d8cbd27b7
# 999  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                   User ID   Type         Category  \
# 0    8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo         Studying
# 1    beb1f34e-7870-46d6-9fc7-2e12eb83ce43  photo   healthy eating
# 2    a5c65404-5894-4b87-82f2-d787cbee86b4  photo   healthy eating
# 3    9fb4ce88-fac1-406c-8544-1a899cee7aaf  photo       technology
# 4    e206e31b-5f85-4964-b6ea-d7ee5324def1  video             food
# ...

# %%
df_content_clean = df_content.dropna()

# %%
df_content_clean.isnull().sum()
# Out:
# Content ID    0
# User ID       0
# Type          0
# Category      0
# URL           0
# dtype: int64

# %%
df_content_clean.to_csv('Content Clean.csv', index=False)

# %%
df_content.head()
# Out:
#                              Content ID                               User ID  \
# 0  97522e57-d9ab-4bd6-97bf-c24d952602d2  8d3cd87d-8a31-4935-9a4f-b319bfe05f31
# 1  9f737e0a-3cdd-4d29-9d24-753f4e3be810  beb1f34e-7870-46d6-9fc7-2e12eb83ce43
# 2  230c4e4d-70c3-461d-b42c-ec09396efb3f  a5c65404-5894-4b87-82f2-d787cbee86b4
# 3  356fff80-da4d-4785-9f43-bc1261031dc6  9fb4ce88-fac1-406c-8544-1a899cee7aaf
# 4  01ab84dd-6364-4236-abbb-3f237db77180  e206e31b-5f85-4964-b6ea-d7ee5324def1
#
#     Type        Category                                                URL
# 0  photo        Studying  https://socialbuzz.cdn.com/content/storage/975...
# 1  photo  healthy eating  https://socialbuzz.cdn.com/content/storage/9f7...
# 2  photo  healthy eating  https://socialbuzz.cdn.com/content/storage/230...
# 3  photo      technology  https://socialbuzz.cdn.com/content/storage/356...
# 4  video            food  https://socialbuzz.cdn.com/content/storage/01a...

# %%
df_react = pd.read_csv("/content/Reactions.csv", index_col = 0 )
df_react
# Out:
#                                  Content ID  \
# 0      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4      97522e57-d9ab-4bd6-97bf-c24d952602d2
# ...                                     ...
# 25548  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25549  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25550  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25551  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25552  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                     User ID        Type             Datetime
# 0                                       NaN         NaN  2021-04-22 15:17:15
# 1      5d454588-283d-459d-915d-c48a2cb4c27f     disgust  2020-11-07 09:43:50
# 2      92b87fa5-f271-43e0-af66-84fac21052e6     dislike  2021-06-17 12:22:51
# 3      163daa38-8b77-48c9-9af6-37a6c1447ac2      scared  2021-04-18 05:13:58
# ...

# %%
df_react_clean = df_react.dropna()
df_react_clean.isnull().sum()
# Out:
# Content ID    0
# User ID       0
# Type          0
# Datetime      0
# dtype: int64

# %%
df_react_clean.to_csv('Reaction Clean.csv', index=False)

# %%
df_reacttype = pd.read_csv("/content/ReactionTypes.csv", index_col = 0 )
df_reacttype
# Out:
#            Type Sentiment  Score
# 0         heart  positive     60
# 1          want  positive     70
# 2       disgust  negative      0
# 3          hate  negative      5
# 4    interested  positive     30
# 5   indifferent   neutral     20
# 6          love  positive     65
# 7    super love  positive     75
# 8       cherish  positive     70
# 9         adore  positive     72
# 10         like  positive     50
# 11      dislike  negative     10
# 12    intrigued  positive     45
# 13      peeking   neutral     35
# 14       scared  negative     15
# 15      worried  negative     12

# %%
merged_df = pd.merge(df_react_clean , df_reacttype , on='Type', how='inner')
merged_df
# Out:
#                                  Content ID  \
# 0      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3      9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 4      230c4e4d-70c3-461d-b42c-ec09396efb3f
# ...                                     ...
# 22529  435007a5-6261-4d8b-b0a4-55fdc189754b
# 22530  435007a5-6261-4d8b-b0a4-55fdc189754b
# 22531  4e4c9690-c013-4ee7-9e66-943d8cbd27b7
# 22532  4e4c9690-c013-4ee7-9e66-943d8cbd27b7
# 22533  4e4c9690-c013-4ee7-9e66-943d8cbd27b7
#
#                                     User ID     Type             Datetime  \
# 0      5d454588-283d-459d-915d-c48a2cb4c27f  disgust  2020-11-07 09:43:50
# 1      34e8add9-0206-47fd-a501-037b994650a2  disgust  2021-01-06 19:13:01
# 2      13c06e7e-833d-47eb-a790-5e09ccfd8d2c  disgust  2021-04-09 02:46:20
# 3      8b49caad-bcc5-43de-bf40-34a66ff8805c  disgust  2021-03-28 21:15:26
# ...

# %%
merged_df1 = pd.merge(df_content_clean, merged_df , on='Content ID', how='inner')
merged_df1
# Out:
#                                  Content ID  \
# 0      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4      97522e57-d9ab-4bd6-97bf-c24d952602d2
# ...                                     ...
# 18379  75d6b589-7fae-4a6d-b0d0-752845150e56
# 18380  75d6b589-7fae-4a6d-b0d0-752845150e56
# 18381  75d6b589-7fae-4a6d-b0d0-752845150e56
# 18382  75d6b589-7fae-4a6d-b0d0-752845150e56
# 18383  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                   User ID_x Type_x    Category  \
# 0      8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo    Studying
# 1      8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo    Studying
# 2      8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo    Studying
# 3      8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo    Studying
# 4      8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo    Studying
# ...

# %%
merged_df1.isnull().sum()
# Out:
# Content ID    0
# User ID_x     0
# Type_x        0
# Category      0
# URL           0
# User ID_y     0
# Type_y        0
# Datetime      0
# Sentiment     0
# Score         0
# dtype: int64

# %%
merged_df1.to_csv('Merged Clean.csv', index=False)

# %%
a = ['User ID_x', 'URL','User ID_y']

# %%
merged_df1 = merged_df1.drop( a , axis=1)

# %%
merged_df1
# Out:
#                                  Content ID Type_x    Category     Type_y  \
# 0      97522e57-d9ab-4bd6-97bf-c24d952602d2  photo    Studying    disgust
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2  photo    Studying    disgust
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2  photo    Studying    disgust
# 3      97522e57-d9ab-4bd6-97bf-c24d952602d2  photo    Studying    dislike
# 4      97522e57-d9ab-4bd6-97bf-c24d952602d2  photo    Studying    dislike
# ...                                     ...    ...         ...        ...
# 18379  75d6b589-7fae-4a6d-b0d0-752845150e56  audio  technology    worried
# 18380  75d6b589-7fae-4a6d-b0d0-752845150e56  audio  technology       like
# 18381  75d6b589-7fae-4a6d-b0d0-752845150e56  audio  technology  intrigued
# 18382  75d6b589-7fae-4a6d-b0d0-752845150e56  audio  technology  intrigued
# 18383  75d6b589-7fae-4a6d-b0d0-752845150e56  audio  technology  intrigued
#
#                   Datetime Sentiment  Score
# ...

# %%
merged_df1.rename(columns={'Type_x': 'Content Type'}, inplace=True)

# %%
merged_df1.rename(columns={'Type_y': 'Reaction Type'}, inplace=True)

# %%
merged_df1
# Out:
#                                  Content ID Content Type    Category  \
# 0      97522e57-d9ab-4bd6-97bf-c24d952602d2        photo    Studying
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2        photo    Studying
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2        photo    Studying
# 3      97522e57-d9ab-4bd6-97bf-c24d952602d2        photo    Studying
# 4      97522e57-d9ab-4bd6-97bf-c24d952602d2        photo    Studying
# ...                                     ...          ...         ...
# 18379  75d6b589-7fae-4a6d-b0d0-752845150e56        audio  technology
# 18380  75d6b589-7fae-4a6d-b0d0-752845150e56        audio  technology
# 18381  75d6b589-7fae-4a6d-b0d0-752845150e56        audio  technology
# 18382  75d6b589-7fae-4a6d-b0d0-752845150e56        audio  technology
# 18383  75d6b589-7fae-4a6d-b0d0-752845150e56        audio  technology
#
#       Reaction Type             Datetime Sentiment  Score
# 0           disgust  2020-11-07 09:43:50  negative      0
# ...

# %%
merged_df1 = pd.read_csv("/content/Merged Fix.csv", index_col = 0 )
merged_df1
# Out:
#                                      Content Type    Category Reaction Type  \
# Content ID
# 97522e57-d9ab-4bd6-97bf-c24d952602d2        photo    Studying       disgust
# 97522e57-d9ab-4bd6-97bf-c24d952602d2        photo    Studying       disgust
# 97522e57-d9ab-4bd6-97bf-c24d952602d2        photo    Studying       disgust
# 97522e57-d9ab-4bd6-97bf-c24d952602d2        photo    Studying       dislike
# 97522e57-d9ab-4bd6-97bf-c24d952602d2        photo    Studying       dislike
# ...                                           ...         ...           ...
# 75d6b589-7fae-4a6d-b0d0-752845150e56        audio  technology       worried
# 75d6b589-7fae-4a6d-b0d0-752845150e56        audio  technology          like
# 75d6b589-7fae-4a6d-b0d0-752845150e56        audio  technology     intrigued
# 75d6b589-7fae-4a6d-b0d0-752845150e56        audio  technology     intrigued
# 75d6b589-7fae-4a6d-b0d0-752845150e56        audio  technology     intrigued
#
# ...

# %%
category_counts = merged_df1['Category'].value_counts()
category_counts
# Out:
# travel             1368
# science            1351
# animals            1323
# healthy eating     1303
# cooking            1277
# culture            1217
# food               1183
# tennis             1153
# technology         1150
# education          1127
# soccer             1065
# fitness            1050
# dogs               1047
# veganism            948
# studying            911
# public speaking     911
# Name: Category, dtype: int64

# %%
merged_df1['Category'] = merged_df1['Category'].replace('Studying', 'studying', regex=True)

# %%
category_counts = merged_df1['Category'].value_counts()
category_counts = category_counts.sort_values(ascending=False)

plt.figure(figsize=(8, 6))
category_counts.plot(kind='barh')


plt.xlabel('Category')
plt.ylabel('Count')
plt.title('Category Count')

plt.show()

# %%
merged_df1.to_csv('Merged Fix Only.csv', index=False)

# %% [markdown]
# # EDA

# %%
df = pd.read_csv("/content/Merged Fix Only.csv" )
df
# Out:
#       Content Type    Category Reaction Type             Datetime Sentiment  \
# 0            photo    studying       disgust  2020-11-07 09:43:50  negative
# 1            photo    studying       disgust  2021-01-06 19:13:01  negative
# 2            photo    studying       disgust  2021-04-09 02:46:20  negative
# 3            photo    studying       dislike  2021-06-17 12:22:51  negative
# 4            photo    studying       dislike  2020-11-09 02:49:59  negative
# ...            ...         ...           ...                  ...       ...
# 18379        audio  technology       worried  2020-11-04 20:08:31  negative
# 18380        audio  technology          like  2021-06-07 03:55:33  positive
# 18381        audio  technology     intrigued  2020-08-26 10:22:22  positive
# 18382        audio  technology     intrigued  2021-04-09 08:05:56  positive
# 18383        audio  technology     intrigued  2021-02-16 17:17:02  positive
#
#        Score
# 0          0
# 1          0
# ...

# %%
df['Score'].mean()
# Out:
# 39.75875761531767

# %%
ctype = df['Content Type'].value_counts()
ctype
# Out:
# photo    5006
# video    4637
# GIF      4465
# audio    4276
# Name: Content Type, dtype: int64

# %%
rtype = df['Reaction Type'].value_counts()
rtype
# Out:
# heart          1225
# scared         1174
# interested     1169
# indifferent    1167
# super love     1167
# love           1165
# peeking        1157
# want           1154
# hate           1153
# adore          1148
# disgust        1142
# like           1132
# cherish        1119
# worried        1112
# dislike        1109
# intrigued      1091
# Name: Reaction Type, dtype: int64

# %%
sentiment = df['Sentiment'].value_counts()
sentiment
# Out:
# positive    10370
# negative     5690
# neutral      2324
# Name: Sentiment, dtype: int64

# %%
sentiment = df['Sentiment'].value_counts()

plt.figure(figsize=(8, 8))
plt.pie(sentiment, labels=sentiment.index, autopct='%1.1f%%')


plt.title('Sentiment Percentage')
plt.show()
